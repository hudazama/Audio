# %% [markdown]
# <a href="https://colab.research.google.com/github/hudazama/Audio/blob/master/CarvanaMasking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle --upgrade -q
# !pip install imageio -q

# %%
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 2.x selected.
# 2.1.0

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import imageio
import matplotlib.pyplot as plt
import cv2

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e70f2af3-8902-41bb-b662-4312b64d79d8" name="files[]" multiple disabled />
#      <output id="result-e70f2af3-8902-41bb-b662-4312b64d79d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"hudazama","key":"df9c2b94daca0f51d36a6942835857f6"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

#download Carvana competition data into colab
# !kaggle competitions download -c carvana-image-masking-challenge
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading train_masks.csv.zip to /content
#  59% 9.00M/15.3M [00:00<00:00, 40.2MB/s]
# 100% 15.3M/15.3M [00:00<00:00, 50.7MB/s]
# Downloading train_hq.zip to /content
# 100% 801M/804M [00:06<00:00, 131MB/s]
# 100% 804M/804M [00:06<00:00, 139MB/s]
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/202k [00:00<?, ?B/s]
# 100% 202k/202k [00:00<00:00, 201MB/s]
# Downloading test_hq.zip to /content
# 100% 15.4G/15.4G [06:37<00:00, 39.1MB/s]
# 100% 15.4G/15.4G [06:37<00:00, 41.8MB/s]
# Downloading test.zip to /content
# 100% 7.75G/7.76G [03:26<00:00, 39.1MB/s]
# 100% 7.76G/7.76G [03:26<00:00, 40.3MB/s]
# Downloading 29bb3ece3180_11.jpg to /content
#   0% 0.00/107k [00:00<?, ?B/s]
# 100% 107k/107k [00:00<00:00, 111MB/s]
# Downloading train_masks.zip to /content
#  31% 9.00M/29.1M [00:00<00:00, 34.2MB/s]
# 100% 29.1M/29.1M [00:00<00:00, 83.5MB/s]
# Downloading metadata.csv.zip to /content
#   0% 0.00/81.2k [00:00<?, ?B/s]
# 100% 81.2k/81.2k [00:00<00:00, 52.1MB/s]
# Downloading train.zip to /content
# 100% 404M/405M [00:06<00:00, 37.1MB/s]
# 100% 405M/405M [00:06<00:00, 64.7MB/s]

# %%
#unzip the training data
# !unzip -q train.zip 
# !unzip -q train_masks.zip 
# !unzip -q train_masks.csv.zip 
# !unzip -q metadata.csv.zip 
#!unzip -q train_hq.zip

# %%
train_csv = pd.read_csv('metadata.csv')
train_csv.head()
# Out:
#              id    year       make   model   trim1                    trim2
# 0  0004d4463b50  2014.0      Acura      TL      TL                     w/SE
# 1  00087a6bd4dc  2014.0      Acura     RLX     RLX                   w/Tech
# 2  000aa097d423  2012.0      Mazda  MAZDA6  MAZDA6                  i Sport
# 3  000f19f6e7d4  2016.0  Chevrolet  Camaro  Camaro                       SS
# 4  00144e887ae9  2015.0      Acura     TLX     TLX  SH-AWD V6 w/Advance Pkg

# %% [markdown]
# Load & resize data, data augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# we create two instances with the same arguments
data_gen_args = dict(rescale=1./255,
                     rotation_range=90.,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     zoom_range=0.2,
                     horizontal_flip=True,
                     vertical_flip=True,
                     shear_range=0.2,
                     brightness_range=(0.5, 1.0),
                     validation_split=0.2
                    )
image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)

# %%
def dice_coef(y_true, y_pred):
    y_true = tf.round(tf.reshape(y_true, [-1]))
    y_pred = tf.round(tf.reshape(y_pred, [-1]))
    isct = tf.reduce_sum(y_true * y_pred)
    return 2 * isct / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred))

# %%
#split dataset
import os 
import glob
from sklearn.model_selection import train_test_split

train_mask = pd.read_csv('train_masks.csv')
filenames = train_mask['img']
train_filenames, val_test_filenames = train_test_split(filenames, test_size = 0.15)
val_filenames, test_filenames = train_test_split(val_test_filenames, test_size = 1/3)

# %%
os.makedirs('../content/data', exist_ok=True)
new_folders = ['training_images','training_masks','valid_images','valid_masks','test_images','test_masks']

for f in new_folders:
  os.makedirs('../content/data/' + f)
  os.makedirs('../content/data/' + f + '/0')

# %%
#Locate training, validation and testing images into respective folder
imagedir = '../content/train/'
maskdir = '../content/train_masks/' 
data_dir = '../content/data/'

for fname in train_filenames:
  os.rename(imagedir + fname, data_dir + 'training_images/0/' + fname)

for fname in val_filenames:
  os.rename(imagedir + fname, data_dir + 'valid_images/0/' + fname)

for fname in test_filenames:
  os.rename(imagedir + fname, data_dir + 'test_images/0/' + fname)

# %%
#Locate training, validation and testing masks into respective folder 

for fname in train_filenames:
  os.rename(maskdir + fname[:-4] + '_mask.gif', data_dir + 'training_masks/0/' + fname)

for fname in val_filenames:
  os.rename(maskdir + fname[:-4] + '_mask.gif', data_dir + 'valid_masks/0/' + fname)

for fname in test_filenames:
  os.rename(maskdir + fname[:-4] + '_mask.gif', data_dir + 'test_masks/0/' + fname)

# %%
import PIL
from PIL import Image
seed = 1
img_size = 256

image_args = dict(seed=seed,
    batch_size=32,
    shuffle=True,
    class_mode=None,
    target_size=(img_size, img_size),
    color_mode='rgb')

mask_args = dict(seed=seed,
    batch_size=32,
    class_mode=None,
    shuffle=True,
    target_size=(img_size, img_size), 
    color_mode='grayscale')

DIR = '/content/data/'
image = 'images'
masks = 'masks'

# combine generators into one which yields image and masks
train_generator = zip(image_datagen.flow_from_directory(**image_args, directory=DIR+'training_'+image),  
                      mask_datagen.flow_from_directory(**mask_args, directory=DIR+'training_'+masks))

validation_generator = zip(image_datagen.flow_from_directory(**image_args, directory=DIR+'valid_'+image),  
                      mask_datagen.flow_from_directory(**mask_args, directory=DIR+'valid_'+masks))
# Out:
# Found 4324 images belonging to 1 classes.
# Found 4324 images belonging to 1 classes.
# Found 509 images belonging to 1 classes.
# Found 509 images belonging to 1 classes.

# %%
img1, mask1 = next(validation_generator)

# %%
fig=plt.figure(figsize=(12,12))
columns = 2
rows = 5
counter = 0
c = 0
for i in range(1, columns*rows +1):
    #img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    if counter%2 == 0:
        plt.imshow(img1[c])
    else:
        plt.imshow(mask1[c][:,:,0])
        c = c + 1
    counter = counter + 1
    

plt.tight_layout()
plt.savefig('augmented.png')
plt.show()

# %% [markdown]
# UNET

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, Lambda, RepeatVector, Reshape, MaxPooling2D, concatenate, BatchNormalization, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
import h5py

# %%
# Provide the same seed and keyword arguments to the fit and flow methods
seed = 1
img_size = 256
im_width = 256
im_height = 256
im_chan = 3

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def get_unet(input_img, n_filters, dropout, batchnorm):
    # DOWN
    c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    p1 = MaxPooling2D((2, 2)) (c1)
    p1 = Dropout(dropout*0.5)(p1)

    c2 = conv2d_block(p1, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    p2 = MaxPooling2D((2, 2)) (c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)
    p3 = MaxPooling2D((2, 2)) (c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters=n_filters*16, kernel_size=3, batchnorm=batchnorm)
    
    # UP
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
input_img = Input((im_height, im_width, im_chan), name='img')
model = get_unet(input_img, n_filters=16, dropout=0.1, batchnorm=True)

model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 16) 448         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 16) 64          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 16) 64          conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 16) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 16) 0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 32) 4640        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 32) 128         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 32) 9248        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 32) 128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 32) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 32)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 32)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 64)   36928       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 64)   0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 128)  147584      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 128)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 128)  0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 256)  295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 256)  1024        conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 32, 32, 128)  295040      activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_4[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 256)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 128)  295040      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 128)  512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 64)   73792       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_5[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 128)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 64)   73792       dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 32) 18464       activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_6[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128, 128, 64) 0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 128, 128, 32) 18464       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 32) 128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 128, 128, 32) 9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 32) 128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 128, 128, 32) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 16) 4624        activation_17[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_7[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256, 256, 32) 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 256, 256, 16) 4624        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 256, 256, 16) 64          conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 256, 256, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 256, 256, 16) 2320        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 256, 16) 64          conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 256, 256, 16) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 256, 256, 1)  17          activation_19[0][0]
# ==================================================================================================
# Total params: 2,164,593
# Trainable params: 2,161,649
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
callbacks = [EarlyStopping(monitor='val_loss',
                           patience=5,
                           verbose=1),
             ReduceLROnPlateau(monitor='val_loss',
                               factor=0.2,
                               patience=5,
                               verbose=1),
             ModelCheckpoint(monitor='val_loss',
                             filepath='best_weights.hdf5',
                             save_best_only=True,
                             save_weights_only=True),
             TensorBoard(log_dir='./log',
                         write_graph=True,
                         write_images=True)]

# %%
results = model.fit_generator(train_generator, steps_per_epoch=135,  epochs=50, validation_data=validation_generator, validation_steps=16, callbacks=callbacks)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 135 steps, validate for 16 steps
# Epoch 1/50
# 135/135 [==============================] - 308s 2s/step - loss: 0.3063 - accuracy: 0.7484 - val_loss: 0.4158 - val_accuracy: 0.7830
# Epoch 2/50
# 135/135 [==============================] - 294s 2s/step - loss: 0.1915 - accuracy: 0.7699 - val_loss: 0.4391 - val_accuracy: 0.7804
# Epoch 3/50
# 135/135 [==============================] - 293s 2s/step - loss: 0.1654 - accuracy: 0.7735 - val_loss: 0.4004 - val_accuracy: 0.7775
# Epoch 4/50
# 135/135 [==============================] - 291s 2s/step - loss: 0.1592 - accuracy: 0.7715 - val_loss: 0.3422 - val_accuracy: 0.7703
# Epoch 5/50
# 135/135 [==============================] - 289s 2s/step - loss: 0.1525 - accuracy: 0.7730 - val_loss: 0.2358 - val_accuracy: 0.7669
# Epoch 6/50
# 135/135 [==============================] - 290s 2s/step - loss: 0.1576 - accuracy: 0.7706 - val_loss: 0.2345 - val_accuracy: 0.7658
# Epoch 7/50
# 135/135 [==============================] - 289s 2s/step - loss: 0.1509 - accuracy: 0.7739 - val_loss: 0.2469 - val_accuracy: 0.7663
# Epoch 8/50
# 135/135 [==============================] - 289s 2s/step - loss: 0.1476 - accuracy: 0.7733 - val_loss: 0.2051 - val_accuracy: 0.7695
# Epoch 9/50
# 135/135 [==============================] - 312s 2s/step - loss: 0.1481 - accuracy: 0.7739 - val_loss: 0.1964 - val_accuracy: 0.7665
# Epoch 10/50
# 135/135 [==============================] - 300s 2s/step - loss: 0.1468 - accuracy: 0.7731 - val_loss: 0.2069 - val_accuracy: 0.7713
# Epoch 11/50
# 135/135 [==============================] - 296s 2s/step - loss: 0.1454 - accuracy: 0.7746 - val_loss: 0.1933 - val_accuracy: 0.7665
# Epoch 12/50
# 135/135 [==============================] - 297s 2s/step - loss: 0.1466 - accuracy: 0.7738 - val_loss: 0.2008 - val_accuracy: 0.7662
# Epoch 13/50
# 135/135 [==============================] - 294s 2s/step - loss: 0.1484 - accuracy: 0.7730 - val_loss: 0.1831 - val_accuracy: 0.7623
# Epoch 14/50
# 135/135 [==============================] - 293s 2s/step - loss: 0.1482 - accuracy: 0.7732 - val_loss: 0.1885 - val_accuracy: 0.7692
# Epoch 15/50
# 135/135 [==============================] - 296s 2s/step - loss: 0.1472 - accuracy: 0.7746 - val_loss: 0.1862 - val_accuracy: 0.7672
# Epoch 16/50
# 135/135 [==============================] - 294s 2s/step - loss: 0.1514 - accuracy: 0.7722 - val_loss: 0.2038 - val_accuracy: 0.7651
# Epoch 17/50
# 135/135 [==============================] - 290s 2s/step - loss: 0.1433 - accuracy: 0.7742 - val_loss: 0.2162 - val_accuracy: 0.7618
# Epoch 18/50
# 134/135 [============================>.] - ETA: 1s - loss: 0.1440 - accuracy: 0.7751
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 135/135 [==============================] - 289s 2s/step - loss: 0.1439 - accuracy: 0.7751 - val_loss: 0.2015 - val_accuracy: 0.7616
# Epoch 00018: early stopping

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
img, mask = next(validation_generator)
mask_test = model.predict(img[1][np.newaxis, :])

# %%
plt.imshow(img[1])

# %%
plt.imshow(mask_test[0,:,:,0])
